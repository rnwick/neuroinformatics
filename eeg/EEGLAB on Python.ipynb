# %%
# import dataset from EEGLAB
from oct2py import octave
octave.addpath('../../data/eeglab/functions/guifunc');
octave.addpath('../../data/eeglab/functions/popfunc');
octave.addpath('../../data/eeglab/functions/adminfunc');
octave.addpath('../../data/eeglab/functions/sigprocfunc');
octave.addpath('../../data/eeglab/functions/miscfunc');
EEG = octave.pop_loadset('../../data/eeglab/sample_data/eeglab_data_epochs_ica.set');
# Out:
# ...
# pop_loadset(): loading file ../../data/eeglab/sample_data/eeglab_data_epochs_ica.set ...
# ...
#     eeg_hist at line 53 column 21
#     eeg_checkset at line 1269 column 13
#     pop_loadset at line 224 column 9
#     _pyeval at line 57 column 30
#
# Reading float file '../../data/eeglab/sample_data/eeglab_data_epochs_ica.fdt'...
# ...
# Scaling components to RMS microvolt

# %%
# plot first trial of channel 1
import matplotlib.pyplot as plt
plt.plot(EEG.data[0][:]);
plt.show()
